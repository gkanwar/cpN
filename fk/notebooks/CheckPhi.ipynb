# %% [markdown]
# # Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import tqdm.auto as tqdm
# %matplotlib widget

# %%
res = np.load('../data/fk_phi_b4.0_Nc3_64_64.npy', allow_pickle=True).item()

# %%
fig, ax = plt.subplots(1,1)
ax.hist(res['phi'], bins=30)
plt.show()
